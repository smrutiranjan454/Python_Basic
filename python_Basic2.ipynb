# %%
#5.explain the concept of type casting in python with examples

#Type casting, also known as type conversion, is the process of converting a variable from one data type to another. In Python, type casting can be done using built-in functions. There are two types of type casting:

#      Implicit Type Casting: The Python interpreter automatically converts one data type to another without the programmer's intervention.
#     Explicit Type Casting: The programmer manually converts one data type to another using built-in functions.
   
#      Implicit Type Casting:
#             In implicit type casting, Python automatically converts a smaller data type to a larger data type to prevent data loss.

# Example:


            # Implicit type casting
            x = 10          # int
            y = 2.5         # float

            # x is automatically converted to float and the result is a float
            result = x + y

            print(result)  # Output: 12.5
            print(type(result))  # Output: <class 'float'>
           # In this example, the integer x is implicitly converted to a float during the addition operation to match the type of y, resulting in a float.

#             Explicit Type Casting
#             In explicit type casting, we use built-in functions to convert a variable from one data type to another.

#             int(): Converts a variable to an integer.
#             float(): Converts a variable to a float.
#             str(): Converts a variable to a string.
#             list(): Converts a variable to a list.
#             tuple(): Converts a variable to a tuple.
#             set(): Converts a variable to a set.
#             dict(): Converts a variable to a dictionary (provided it’s a list of key-value pairs).
#             Examples:

            #Converting float to int:

            x = 2.8
            y = int(x)

            print(y)  # Output: 2
            print(type(y))  # Output: <class 'int'>
            #Converting int to float:

            x = 5
            y = float(x)

            print(y)  # Output: 5.0
            print(type(y))  # Output: <class 'float'>
            #Converting int to string:

            x = 10
            y = str(x)

            print(y)  # Output: '10'
            print(type(y))  # Output: <class 'str'>
           # Converting string to int:

            x = "15"
            y = int(x)

            print(y)  # Output: 15
            print(type(y))  # Output: <class 'int'>
            #Converting list to tuple:

            x = [1, 2, 3]
            y = tuple(x)

            print(y)  # Output: (1, 2, 3)
            print(type(y))  # Output: <class 'tuple'>
           # Converting tuple to list:

            x = (1, 2, 3)
            y = list(x)

            print(y)  # Output: [1, 2, 3]
            print(type(y))  # Output: <class 'list'>
            #Converting list of tuples to dictionary:

            x = [("a", 1), ("b", 2), ("c", 3)]
            y = dict(x)

            print(y)  # Output: {'a': 1, 'b': 2, 'c': 3}
            print(type(y))  # Output: <class 'dict'>
            
 #  6.how do conditional statement work in python ? illustrate with examples    
    
     #Conditional statements in Python allow you to execute certain pieces of code based on whether a condition is true or false. The primary conditional statements in Python are if, elif, and else.

        # Syntax and Structure
        # if statement
        # elif statement
        # else statement
        
        
        # 1. if Statement
        # The if statement evaluates a condition. If the condition is true, it executes the corresponding block of code.

               # Example:

               
                x = 10
                if x > 5:
                    print("x is greater than 5")
#                 Output: x is greater than 5
                # 2. elif Statement
                # The elif statement allows you to check multiple conditions, one after another. If the first condition is false, it checks the next condition, and so on.

                #Example:

                x = 10
                if x > 15:
                    print("x is greater than 15")
                elif x > 5:
                    print("x is greater than 5 but less than or equal to 15")
                else:
                    print("x is 5 or less")
                #Output:x is greater than 5 but less than or equal to 15
                # 3. else Statement
                  # The else statement catches anything which isn't caught by the preceding conditions.

                # Example:
                x = 3
                if x > 5:
                    print("x is greater than 5")
                elif x > 2:
                    print("x is greater than 2 but less than or equal to 5")
                else:
                    print("x is 2 or less")
              #  Output: x is greater than 2 but less than or equal to 5
            
                In Python, loops are used to repeatedly execute a block of code as long as a condition is met. There are two primary types of loops in Python:

        # for loop
        # while loop
         
            # 1. for Loop
        # The for loop in Python is used for iterating over a sequence (such as a list, tuple, dictionary, set, or string). This is more like an iterator method found in other object-oriented programming languages.

            Syntax:


            for item in sequence:
                # Code block to be executed
#             Use Cases:

#             Iterating over a list:
            fruits = ["apple", "banana", "cherry"]
            for fruit in fruits:
                print(fruit)
#             Output:

#             Copy code
#             apple
#             banana
#             cherry
            # Iterating over a string:
           for char in "Python":
                print(char)
            # Output:
            # P
            # y
            # t
            # h
            # o
            # n
            # Using range() to generate a sequence of numbers:

            for i in range(5):
                print(i)
            # Output:
            # 0
            # 1
            # 2
            # 3
            # 4
            # 2. while Loop
            # The while loop in Python is used to repeatedly execute a block of code as long as a condition is true.

#             Syntax:

#             while condition:
#                 # Code block to be executed
#             Use Cases:

#             Simple counting:
            i = 0
            while i < 5:
                print(i)
                i += 1
            # Output:
            # 0
            # 1
            # 2
            # 3
            # 4
            # Using while loop to keep taking input until a condition is met:

           
            user_input = ""
            while user_input.lower() != "quit":
                user_input = input("Enter something (type 'quit' to stop): ")
                print(f"You entered: {user_input}")
            # Loop Control Statements
            # Python also provides control statements to alter the flow of loops:

           # break: Terminates the loop entirely.
            #continue: Skips the rest of the code inside the loop for the current iteration only and proceeds to the next iteration.
            
            #Examples:

           # Using break:

            for i in range(10):
                if i == 5:
                    break
                print(i)
            # Output:
            # 0
            # 1
            # 2
            # 3
            # 4
           # Using continue:
            for i in range(10):
                if i % 2 == 0:
                    continue
                print(i)
#             Output:
#             1
#             3
#             5
#             7
#             9
            

           
            #Nested Loops
            #Loops can be nested, meaning you can have a loop inside another loop. This is useful for iterating over multi-dimensional data structures.

           # Example:
            for i in range(3):
                for j in range(3):
                    print(f"i = {i}, j = {j}")
            Output:

            i = 0, j = 0
            i = 0, j = 1
            i = 0, j = 2
            i = 1, j = 0
            i = 1, j = 1
            i = 1, j = 2
            i = 2, j = 0
            i = 2, j = 1
            i = 2, j = 2
