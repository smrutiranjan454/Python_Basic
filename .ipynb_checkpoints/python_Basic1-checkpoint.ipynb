# %%
# 1. Explain the key features of Python that make it a popular choice of programming.
#   Ans:-
    #    -> ease to learn
    #    -> powerful & versatile
    #    -> free & open source
    #    -> object oriented language
    #    -> extensive library support 
    # In addition to these key features, Python also offers a number of other features that make it 
    # popular.

# 2. Describe the role of predefined keywords in Python and provide examples of how they are used
#  in program
    
#          -> Python Keywords are some predefined and reserved words in Python that have special meanings.
#         Keywords are used to define the syntax of the coding. The keyword cannot be used as an identifier,
#         function, or variable name.
#         -> These keywords are fundamental to Python programming as they help define the structure and control flow of the code.
#         Here's a description of their roles along with examples of how they are used:
#             We cannot use keywords as variable names as they are reserved names that are built-in to Python. For example,
            #code
            continue = 'Python'
            # The above code is wrong because we have used continue as a variable name.
         # -> if, elif, else: Used for conditional statements.
            #code
              x = 10
                if x > 5:
                    print("x is greater than 5")
                elif x == 5:
                    print("x is 5")
                else:
                    print("x is less than 5")
         # ->By using these predefined keywords appropriately, you can write clear, efficient, and error-free Python code.

#3.   compare and contrast mutable and immutable objects in python in examples. 
#       Mutable Objects
#           Mutable objects are those whose state or contents can be changed after they are created. Common examples of mutable objects in Python include lists, dictionaries, sets, and custom objects.

#          Characteristics of Mutable Objects:
#                        State can be changed: Elements can be added, removed, or modified.
#                           Memory efficiency: Operations like appending or modifying do not create new objects but alter the existing ones.
#                           Iteration effects: Changes to the object during iteration affect the ongoing iteration.  
#                     1.List (mutable)
                      #code
                        my_list = [1, 2, 3]
                        print(my_list)  # Output: [1, 2, 3]

                        my_list.append(4)
                        print(my_list)  # Output: [1, 2, 3, 4]

                        my_list[0] = 10
                        print(my_list)  # Output: [10, 2, 3, 4]
                    # 2.Dictionary (mutable)
                     #code
                        my_dict = {'a': 1, 'b': 2}
                        print(my_dict)  # Output: {'a': 1, 'b': 2}

                        my_dict['c'] = 3
                        print(my_dict)  # Output: {'a': 1, 'b': 2, 'c': 3}

                        my_dict['a'] = 10
                        print(my_dict)  # Output: {'a': 10, 'b': 2, 'c': 3}
     

 #      Immutable Objects
#            Immutable objects are those whose state or contents cannot be changed after they are created. Common examples of immutable objects in Python include integers, floats, strings, tuples, and frozensets.

#               Characteristics of Immutable Objects:
#                     State cannot be changed: Any operation that modifies the object will create a new object.
#                     Memory allocation: Modifying an immutable object results in a new object with a different memory address.
#                      Thread safety: Since their state cannot be changed, immutable objects are inherently thread-safe.
#             1.String (immutable)
             #code
                name_1 = "Aarun" 
                name_1[0] = 'T' 
                         #Output: TypeError: 'str' object does not support item assignment
            # 2.Tuple (immutable)
             #code
                mytuple = (1, 2, 3, 4, 2, 3)
                mytuple[1] = 100
                        #output:TypeError: 'tuple' object does not support item assignment
     
    #4.discuss different types of operators in python and provide examples of how they are used.          
    
    
#     In Python, operators are special symbols that perform operations on variables and values. They are classified into several categories:

#                 1. Arithmetic Operators
#                 2. Assignment Operators
#                 3. Comparison Operators
#                 4. Logical Operators
#                 5. Bitwise Operators
#                 6. Membership Operators
#                 7. Identity Operators
#                              Let's discuss each type with examples:
                 
#             Arithmetic operators are used to perform mathematical operations.
            
#                 Addition (+): Adds two operands.
                     x = 5
                     y = 3
                    print(x + y)  # Output: 8
                # Subtraction (-): Subtracts the second operand from the first.
                    print(x - y)  # Output: 2
                # Multiplication (*): Multiplies two operands.
                     print(x * y)  # Output: 15
                # Division (/): Divides the first operand by the second.
                     print(x / y)  # Output: 1.6666666666666667
                # Modulus (%): Returns the remainder of the division.
                     print(x % y)  # Output: 2
                #Exponentiation ()**: Raises the first operand to the power of the second.
                    print(x ** y)  # Output: 125
               # Floor Division (//): Divides and returns the largest integer less than or equal to the result. 
                    print(x // y)  # Output: 1

          #2.Assignment Operators
                #These operators are used to assign values to variables.
            #Equal (=): Assigns the value of the right operand to the left operand.

                  x = 5
               # Add and Assign (+=): Adds the right operand to the left operand and assigns the result to the left operand.


                x += 3  # x = x + 3; Output: 8
                #Subtract and Assign (-=): Subtracts the right operand from the left operand and assigns the result to the left operand.
                 x -= 2  # x = x - 2; Output: 6
                #Multiply and Assign (*=): Multiplies the left operand by the right operand and assigns the result to the left operand.
                x *= 2  # x = x * 2; Output: 12
                #Divide and Assign (/=): Divides the left operand by the right operand and assigns the result to the left operand.
                 x /= 4  # x = x / 4; Output: 3.0
               # Modulus and Assign (%=): Takes the modulus using the left and right operands and assigns the result to the left operand.
                x %= 3  # x = x % 3; Output: 0.0

           # 3. Comparison (Relational) Operators
                #These operators compare two values and return a Boolean result.

                   # Equal (==): Checks if the values of two operands are equal.


                    x = 5
                    y = 3
                    print(x == y)  # Output: False
                    #Not Equal (!=): Checks if the values of two operands are not equal.
                    print(x != y)  # Output: True
                    #Greater Than (>): Checks if the value of the left operand is greater than the value of the right operand.
                    print(x > y)  # Output: True
                    #Less Than (<): Checks if the value of the left operand is less than the value of the right operand.
                    print(x < y)  # Output: False
                    #Greater Than or Equal To (>=): Checks if the value of the left operand is greater than or equal to the value of the right operand.
                    print(x >= y)  # Output: True
                   # Less Than or Equal To (<=): Checks if the value of the left operand is less than or equal to the value of the right operand.
                    print(x <= y)  # Output: False


           # 4. Logical Operators
                   # These operators are used to combine conditional statements.

                    #and: Returns True if both statements are true.
                    x = 5
                    print(x > 3 and x < 10)  # Output: True
                   # or: Returns True if one of the statements is true.
                    print(x > 3 or x < 4)  # Output: True
                   # not: Reverses the result, returns False if the result is true.
                    print(not(x > 3 and x < 10))  # Output: False
            #5. Bitwise Operators
                    #These operators are used to compare (binary) numbers.

                    #AND (&): Sets each bit to 1 if both bits are 1.
                    x = 5  # 0101
                    y = 3  # 0011
                    print(x & y)  # Output: 1 (0001)
                   # OR (|): Sets each bit to 1 if one of the two bits is 1.
                    print(x | y)  # Output: 7 (0111)
                   # XOR (^): Sets each bit to 1 if only one of the two bits is 1.
                    print(x ^ y)  # Output: 6 (0110)
                    #NOT (~): Inverts all the bits.
                    print(~x)  # Output: -6 (inverts the bits)
                   # Zero-fill left shift (<<): Shifts the bits of the first operand left by the number of places specified by the second operand.
                    print(x << 2)  # Output: 20 (0101 << 2 = 10100)
                   # Signed right shift (>>): Shifts the bits of the first operand right by the number of places specified by the second operand.
                    print(x >> 2)  # Output: 1 (0101 >> 2 = 0001)
           # 6. Membership Operators
                   # These operators are used to test if a sequence is presented in an object.

                  #  in: Returns True if a sequence with the specified value is present in the object.
                    x = "Hello"
                    print("H" in x)  # Output: True
                   # not in: Returns True if a sequence with the specified value is not present in the object.
                    print("h" not in x)  # Output: True
            #7. Identity Operators
                    #These operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location.

                   # is: Returns True if both variables are the same object.
                    x = ["apple", "banana"]
                    y = ["apple", "banana"]
                    z = x
                    print(x is z)  # Output: True
                    print(x is y)  # Output: False
                   # is not: Returns True if both variables are not the same object.
                    print(x is not y)  # Output: True
